# %%
import sys, os
from gensim.models import Word2Vec
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from matplotlib import pyplot
import tqdm as tqdm
from gensim.models import TranslationMatrix
model = Word2Vec.load('embeddings/k_model_300_30_50.pkl')
words=[]
import gensim
import numpy as np
from pathlib import Path
import pickle
from time import time
from typing import List, Dict, Set, Tuple
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.datasets import load_iris
import numpy as np
import gensim
import networkx as nx
from node2vec import Node2Vec
from sklearn.decomposition import PCA

from pandas_profiling import ProfileReport

# %%
# 基于2d PCA拟合数据
X = model.wv[model.wv.index_to_key]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
#result = TSNE(n_components=2).fit_transform(result_pca)
# 可视化展示
pyplot.xticks([]) 
pyplot.yticks([]) 
pyplot.rcParams['font.size'] = 8  # 字体大小
pyplot.rcParams['axes.unicode_minus'] = False  # 正常显示负号
pyplot.figure(figsize=(20,20))
pyplot.scatter(result[:, 0], result[:, 1],color='#86C166')
ad = list(model.wv.index_to_key)
words=[]
for i in range(len(ad)):
	try:
		words.append(int(ad[i]))
	except ValueError:
		words.append(' ')

for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %%
key_index=[116,
 113,
 90,
 9,
 110,
 106,
 89,
 10,
 115,
 104,
 34,
 25,
 75,
 8,
 74,
 35,
 103,
 11,
 108,
 109,
 112,
 54,
 105,
 107,
 87,
 32,
 45,
 55,
 46,
 56,
 13,
 42,
 88,
 58,
 86,
 98,
 43,
 12,
 114,
 47,
 111,
 92,
 72,
 59,
 97,
 85,
 99,
 60,
 38,
 31,
 26,
 44,
 36,
 37,
 50,
 101,
 53,
 84,
 52,
 102,
 68,
 33,
 21,
 22,
 19,
 27,
 29,
 20,
 78,
 94,
 6,
 49,
 51,
 100,
 30,
 18,
 67,
 76,
 7,
 66,
 73,
 48,
 41,
 63,
 79,
 91,
 1,
 83,
 40,
 64,
 23,
 4,
 77,
 28,
 65,
 81,
 14,
 17,
 3,
 61,
 15,
 39,
 96,
 2,
 82,
 5,
 62,
 80,
 95,
 24,
 93,
 69,
 71,
 16,
 70,
 57]

# %%
attrition = 'test.csv'
df_ac = pd.read_csv(attrition,encoding='utf-8')
df_ac
selected_columns = ['K','word']
df_attrition = df_ac.loc[:, selected_columns]
df_attrition
# Out:
#        K    word
# 0      1    백신패스
# 1      2   위드코로나
# 2      3   접종완료자
# 3      4  ウィズコロナ
# 4      5  段階日常回復
# ..   ...     ...
# 111  112     SBN
# 112  113     黙トレ
# 113  114   ウェビナー
# 114  115     당모치
# 115  116     쪄죽따
#
# [116 rows x 2 columns]

# %%
import matplotlib.font_manager as font_manager
from matplotlib import pyplot as plt
# %matplotlib inline
font_path = r'out.ttf'  # 此处改为自己字体的路径
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
plt.rcParams['font.family'] = prop.get_name()

# %%
result[2, 0]
# Out:
# 7.150478

# %%
result=np.loadtxt("pca_result.txt")

# %%
X = model.wv[key_index]
pca = PCA(n_components=3)
result_pca= pca.fit_transform(X)
result = TSNE(n_components=3).fit_transform(result_pca)
# Out:
# /Users/gabrielpondc/miniforge3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/gabrielpondc/miniforge3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# 可视化展示
fig=plt.figure(figsize=(20,20))


ax1=plt.axes(projection='3d')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
ax1.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax1.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax1.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax1.scatter(result[70, 0], result[70, 1],result[70,2],c='#DAC9A6',alpha=0.8,s=500.0, marker="o")
ax1.scatter(result[86, 0], result[86, 1],result[86,2],c='#DAC9A6',alpha=0.8,s=500.0, marker="o")
ax1.scatter(result[97, 0], result[97, 1],result[97,2],c='#DAC9A6',alpha=0.8,s=500.0, marker="o")
ax1.scatter(result[96, 0], result[96, 1],result[96,2],c='#0D5661',alpha=0.8,s=500.0, marker="s")
ax1.scatter(result[100, 0], result[100, 1],result[100,2],c='#0D5661',alpha=0.8,s=500.0, marker="s")
ax1.scatter(result[73, 0], result[73, 1],result[73,2],c='#CB1B45',alpha=0.5,s=500.0, marker="p")
ax1.scatter(result[55, 0], result[55, 1],result[55,2],c='#CB1B45',alpha=0.5,s=500.0, marker="p")
ax1.scatter(result[59, 0], result[59, 1],result[59,2],c='#CB1B45',alpha=0.5,s=500.0, marker="p")

ax1.text(result[70, 0], result[70, 1], result[70, 2], 'ワクチンパスポト').set_fontsize(35)
ax1.text(result[86, 0], result[86, 1],result[86,2], '백신패스').set_fontsize(35)
ax1.text(result[97, 0], result[97, 1],result[97,2], '健康码').set_fontsize(35)
ax1.text(result[96, 0], result[96, 1],result[96,2], '자택치료').set_fontsize(35)
ax1.text(result[100, 0], result[100, 1],result[100,2], '自宅療養').set_fontsize(35)
ax1.text(result[73, 0], result[73, 1],result[73,2], '伸手党').set_fontsize(35)
ax1.text(result[55, 0], result[55, 1],result[55,2], '教えてチャン').set_fontsize(35)
ax1.text(result[59, 0], result[59, 1],result[59,2], '핑프').set_fontsize(35)
plt.savefig('embedding.svg', transparent=True, bbox_inches='tight', pad_inches=0.0)
plt.show()

# %%
# 基于2d PCA拟合数据
X = model.wv[key_index]
pca = PCA(n_components=2)
result_pca = pca.fit_transform(X)
result = TSNE(n_components=2).fit_transform(result_pca)
# 可视化展示
plt.xticks([]) 
plt.yticks([]) 
plt.rcParams['font.size'] = 100  # 字体大小
plt.rcParams['axes.unicode_minus'] = False  # 正常显示负号
plt.figure(figsize=(200,200))
plt.scatter(result[:, 0], result[:, 1],color='#86C166',s=20000,alpha=0.5)
ad = list(key_index)
words=[]
for i in range(len(ad)):
	try:
		words.append(int(ad[i]))
	except ValueError:
		words.append(' ')
ad = list(key_index)
words=[]
for i in range(len(ad)):
	try:
		words.append(int(ad[i]))
	except ValueError:
		words.append(' ')
cword=[]
for i in words:
  try:
    a=df_attrition.loc[df_ac['K']==i]['word']
    cword.append(a.values[0])
  except:
	  cword.append('')
for i, word in enumerate(cword):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %%
X = model.wv[key_index]
pca = PCA(n_components=3)
result_pca= pca.fit_transform(X)
result = TSNE(n_components=3).fit_transform(result_pca)

# %%
# 可视化展示
fig=plt.figure(figsize=(200,200))
ax1=plt.axes(projection='3d')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')


ax1.scatter(result[:, 0], result[:, 1],result[:,2],cmap='blue',alpha=0.5, marker="o",s=30000)

ad = list(key_index)
words=[]
for i in range(len(ad)):
	try:
		words.append(int(ad[i]))
	except ValueError:
		words.append(' ')
cword=[]
for i in words:
  try:
    a=df_attrition.loc[df_ac['K']==i]['word']
    cword.append(a.values[0])
  except:
	  cword.append('')
for i, word in zip(range(len(cword)),cword):
    ax1.text(result[i, 0], result[i, 1], result[i, 2], word).set_fontsize(90)
    
#plt.savefig('embedding.svg', transparent=True, bbox_inches='tight', pad_inches=0.0)
plt.show()
